# %%
from utils import *

# %%
r = 4
g = 3
d = 1 # no tocar
X = Curve("X", g)
J = Jacobian(X).to_lambda()

# %%
obj = motive_generic_clean(X, r, d)

# %%
save_expr(obj, f"{r}_{g}_h1")

# %%
loaded = load_expr(f"{r}_{g}_h1")

# %%
compare(obj, loaded)
# Out:
# True

# %%
obj
# Out:
# L**30 + L**29 + L**28*λ1(h1_X) + 3*L**28 + 2*L**27*λ1(h1_X) + 5*L**27 + 5*L**26*λ1(h1_X) + L**26*λ2(h1_X) + 9*L**26 + L**25*λ1(h1_X)**2 + 9*L**25*λ1(h1_X) + L**25*λ2(h1_X) + 13*L**25 + 2*L**24*λ1(h1_X)**2 + 17*L**24*λ1(h1_X) + 4*L**24*λ2(h1_X) + L**24*λ3(h1_X) + 22*L**24 + 5*L**23*λ1(h1_X)**2 + L**23*λ1(h1_X)*λ2(h1_X) + 27*L**23*λ1(h1_X) + 7*L**23*λ2(h1_X) + L**23*λ3(h1_X) + 29*L**23 + 9*L**22*λ1(h1_X)**2 + 3*L**22*λ1(h1_X)*λ2(h1_X) + 44*L**22*λ1(h1_X) + 14*L**22*λ2(h1_X) + 3*L**22*λ3(h1_X) + 43*L**22 + L**21*λ1(h1_X)**3 + 17*L**21*λ1(h1_X)**2 + 5*L**21*λ1(h1_X)*λ2(h1_X) + L**21*λ1(h1_X)*λ3(h1_X) + 63*L**21*λ1(h1_X) + 21*L**21*λ2(h1_X) + 6*L**21*λ3(h1_X) + 56*L**21 + L**20*λ1(h1_X)**3 + 26*L**20*λ1(h1_X)**2 + 14*L**20*λ1(h1_X)*λ2(h1_X) + 2*L**20*λ1(h1_X)*λ3(h1_X) + 90*L**20*λ1(h1_X) + L**20*λ2(h1_X)**2 + 36*L**20*λ2(h1_X) + 9*L**20*λ3(h1_X) + 73*L**20 + 3*L**19*λ1(h1_X)**3 + L**19*λ1(h1_X)**2*λ2(h1_X) + 42*L**19*λ1(h1_X)**2 + 23*L**19*λ1(h1_X)*λ2(h1_X) + 5*L**19*λ1(h1_X)*λ3(h1_X) + 1
# ...
