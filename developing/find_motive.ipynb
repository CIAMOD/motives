# %%
#El remake ahora con mas mates

# %%
from utils import *

# %%
from time import time

# %%
g = 2
r = 4
d = 1 # dejar así
X = Curve("X", g)
H = X.curve_chow
J = Jacobian(X).get_lambda_var(1)

# %%
motive_H = motive_generic(X, r, d)/J
motive_H_clean = motive_generic_clean(X, r, d)
motive_X = gl(X, r)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 motive_H = motive_generic(X, r, d)/J
# ----> 2 motive_H_clean = motive_generic_clean(X, r, d)
#       3 motive_X = gl(X, r)
#
# File ~/tfg/motives/developing/utils.py:34, in motive_generic_clean(curve, r, d)
#      32 H = curve.curve_chow
#      33 J = Jacobian(curve).get_lambda_var(1)
# ---> 34 return (motive_generic(curve, r, d)/J).expand().simplify().subs({H.get_lambda_var(i): sym_lambda_chow(H, i) for i in range(1, H.g+1)})
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/basic.py:1956, in Basic.simplify(self, **kwargs)
#    1954 """See the simplify function in sympy.simplify"""
#    1955 from sympy.simplify.simplify import simplify
# -> 1956 return simplify(self, **kwargs)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/simplify/simplify.py:658, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     656 expr = _bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     657 expr = Mul(*powsimp(expr).as_content_primitive())
# --> 658 _e = cancel(expr)
#     659 expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     660 expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/polys/polytools.py:7380, in cancel(f, _signsimp, *gens, **args)
#    7378 if f.has(Piecewise):
#    7379     raise PolynomialError()
# -> 7380 R, (F, G) = sring((p, q), *gens, **args)
#    7381 if not R.ngens:
#    7382     if not isinstance(f, Tuple):
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/polys/rings.py:164, in sring(exprs, *symbols, **options)
#     161 opt = build_options(symbols, options)
#     163 # TODO: rewrite this so that it doesn't use expand() (see poly()).
# --> 164 reps, opt = _parallel_dict_from_expr(exprs, opt)
#     166 if opt.domain is None:
#     167     coeffs = sum([ list(rep.values()) for rep in reps ], [])
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/polys/polyutils.py:346, in _parallel_dict_from_expr(exprs, opt)
#     344 """Transform expressions into a multinomial form. """
#     345 if opt.expand is not False:
# --> 346     exprs = [ expr.expand() for expr in exprs ]
#     348 if any(expr.is_commutative is False for expr in exprs):
#     349     raise PolynomialError('non-commutative expressions are not supported')
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/expr.py:3704, in Expr.expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3702     if use_hint:
#    3703         hint = '_eval_expand_' + hint
# -> 3704         expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3706 while True:
#    3707     was = expr
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/expr.py:3643, in Expr._expand_hint(expr, hint, deep, **hints)
#    3640         expr = expr.func(*sargs)
#    3642 if hasattr(expr, hint):
# -> 3643     newexpr = getattr(expr, hint)(**hints)
#    3644     if newexpr != expr:
#    3645         return (newexpr, True)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/mul.py:966, in Mul._eval_expand_mul(self, **hints)
#     964 if sums:
#     965     deep = hints.get("deep", False)
# --> 966     terms = self.func._expandsums(sums)
#     967     args = []
#     968     for term in terms:
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/mul.py:930, in Mul._expandsums(sums)
#     927 left = Mul._expandsums(sums[:L//2])
#     928 right = Mul._expandsums(sums[L//2:])
# --> 930 terms = [Mul(a, b) for a in left for b in right]
#     931 added = Add(*terms)
#     932 return Add.make_args(added)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/operations.py:108, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#     105 if len(args) == 1:
#     106     return args[0]
# --> 108 c_part, nc_part, order_symbols = cls.flatten(args)
#     109 is_commutative = not nc_part
#     110 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/mul.py:703, in Mul.flatten(cls, seq)
#     699     nc_part = [c for c in nc_part if not (fuzzy_not(c.is_zero) and
#     700                                           c.is_extended_real is not None)]
#     702 # 0
# --> 703 elif coeff.is_zero:
#     704     # we know for sure the result will be 0 except the multiplicand
#     705     # is infinity or a matrix
#     706     if any(isinstance(c, MatrixExpr) for c in nc_part):
#     707         return [coeff], nc_part, order_symbols
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/assumptions.py:502, in make_property.<locals>.getit(self)
#     500 except KeyError:
#     501     if self._assumptions is self.default_assumptions:
# --> 502         self._assumptions = self.default_assumptions.copy()
#     503     return _ask(fact, self)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/assumptions.py:482, in StdFactKB.copy(self)
#     481 def copy(self):
# --> 482     return self.__class__(self)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/assumptions.py:479, in StdFactKB.__init__(self, facts)
#     477     self._generator = facts.generator
#     478 if facts:
# --> 479     self.deduce_all_facts(facts)
#
# File ~/tfg/motives/motivesEnv/lib/python3.12/site-packages/sympy/core/facts.py:625, in FactKB.deduce_all_facts(self, facts)
#     623     # lookup routing tables
#     624     for key, value in full_implications[k, v]:
# --> 625         self._tell(key, value)
#     627     beta_maytrigger.update(beta_triggers[k, v])
#     629 # --- beta chains ---
#
# KeyboardInterrupt:

# %%
motive_X
# Out:
# L**16 + L**6*λ2(X)**2 + X**2*(L**11 + L**3) + X*λ2(X)*(L**8 + L**5) + X*λ2(X)*(L**9 + L**4) + X*λ3(X)*(L**7 + L**5) + X*(L**13 + L**2) + X*(L**14 + L) + λ2(X)*(L**10 + L**4) + λ2(X)*(L**12 + L**2) + λ3(X)*(L**7 + L**6) + λ3(X)*(L**10 + L**3) + λ4(X)*(L**8 + L**4) + 1

# %%
def find_motive_dfs(obj, X, coefs, monoms_H, monoms_X, n_rounds):
    def dfs(candidate, big_part, n_monom, n_round):
        if n_monom == len(monoms_H):
            m = find_motive_low(candidate, X)
            if m is not None:
                return (big_part + m).expand()
            return None
        monom = monoms_H[n_monom]
        new_n_monom = n_monom + 1 if n_round==n_rounds-1 else n_monom
        new_n_round = 0 if n_round==n_rounds-1 else n_round+1
        for coef in coefs:
            m = (candidate-coef*monom).expand()
            if any(term.could_extract_minus_sign() for term in m.as_ordered_terms()):
                continue
            result = dfs(m, big_part+coef*monoms_X[n_monom], new_n_monom, new_n_round)
            if result is not None:
                return result
        return None
    res = dfs(obj, 0, 0, 0)
    return [res] if res is not None else []

# %%
t0 = time()
coefs = [0] + [L**i for i in range(9)]
monoms_H = []
monoms_X = []
n_rounds = 2
motives = find_motive_bfs(motive_H_clean, X, coefs, monoms_H, monoms_X, n_rounds)
print(time()-t0)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 20.77it/s]
# 0.05380868911743164

# %%
motive = motives[0]
compare(subs_H(motive, X), motive_H)
# Out:
# True

# %%
len(motives)
# Out:
# 1

# %%
motives[0]
# Out:
# L**15 + L**13*X + L**11*λ2(X) + L**9*λ3(X) + L**7*λ4(X) + L**5*λ5(X) + L**4*λ4(X) + L**3*λ3(X) + L**2*λ2(X) + L*X + 1
